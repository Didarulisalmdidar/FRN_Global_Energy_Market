# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
for i in range(1,13):
    df = pd.read_csv(f'FMin{i}.csv', index_col=0)
    df.columns = name
    threshold_matrix = pd.DataFrame(0, columns=df.columns, index=df.columns)
    for index, row in df.iterrows():
        for column in df.columns:
            value = df.loc[index, column]
            if(value>=threshold):
                threshold_matrix[column][index]=1
             
            else:
                threshold_matrix[column][index]=0 
    threshold_matrix.to_csv('TMin{}.csv'.format(i))
